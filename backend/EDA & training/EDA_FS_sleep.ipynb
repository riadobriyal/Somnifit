# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../datasets/sleep_dataset.csv')
df.head()
# Out:
#   Person ID        Date  Sleep Duration (hrs)  Sleep Efficiency (%)  \
# 0  Person_1  2025-05-29              6.763567                 76.10
# 1  Person_2  2025-05-29              7.101986                 78.30
# 2  Person_3  2025-05-29              6.726011                 75.96
# 3  Person_4  2025-05-29              7.179961                 78.98
# 4  Person_5  2025-05-29              6.877313                 76.99
#
#               Bed Time                   Wake Up Time  Deep Sleep (hrs)  \
# 0  2025-05-31 23:06:00  2025-06-01 05:51:48.842830288          0.970121
# 1  2025-05-31 21:41:00  2025-06-01 04:47:07.148024820          0.962702
# 2  2025-05-31 23:40:00  2025-06-01 06:23:33.640384918          0.885353
# 3  2025-05-31 21:34:00  2025-06-01 04:44:47.859080926          1.045949
# 4  2025-05-31 22:55:00  2025-06-01 05:47:38.327794910          1.320055
#
#    Light Sleep (hrs)  REM Sleep (hrs)  Time unable to sleep/Others (hrs)  Age  \
# 0           2.700219         1.495712                           1.597515   56
# 1           3.172448         1.634347                           1.332489   46
# 2           2.813898         1.665220                           1.361541   32
# 3           2.985220         1.672419                           1.476373   60
# 4           2.794770         1.558585                           1.203904   25
#
#    Gender
# 0    Male
# 1  Female
# 2    Male
# 3  Female
# 4    Male

# %%
df['Bed Time'] = pd.to_datetime(df['Bed Time'])
df['Wake Up Time'] = pd.to_datetime(df['Wake Up Time'])
df['Bed_time_hours'] = df['Bed Time'].dt.hour
df['Wakeup_time_hours'] = df['Wake Up Time'].dt.hour
df.head()
# Out:
#   Person ID        Date  Sleep Duration (hrs)  Sleep Efficiency (%)  \
# 0  Person_1  2025-05-29              6.763567                 76.10
# 1  Person_2  2025-05-29              7.101986                 78.30
# 2  Person_3  2025-05-29              6.726011                 75.96
# 3  Person_4  2025-05-29              7.179961                 78.98
# 4  Person_5  2025-05-29              6.877313                 76.99
#
#              Bed Time                  Wake Up Time  Deep Sleep (hrs)  \
# 0 2025-05-31 23:06:00 2025-06-01 05:51:48.842830288          0.970121
# 1 2025-05-31 21:41:00 2025-06-01 04:47:07.148024820          0.962702
# 2 2025-05-31 23:40:00 2025-06-01 06:23:33.640384918          0.885353
# 3 2025-05-31 21:34:00 2025-06-01 04:44:47.859080926          1.045949
# 4 2025-05-31 22:55:00 2025-06-01 05:47:38.327794910          1.320055
#
#    Light Sleep (hrs)  REM Sleep (hrs)  Time unable to sleep/Others (hrs)  Age  \
# 0           2.700219         1.495712                           1.597515   56
# 1           3.172448         1.634347                           1.332489   46
# 2           2.813898         1.665220                           1.361541   32
# 3           2.985220         1.672419                           1.476373   60
# 4           2.794770         1.558585                           1.203904   25
#
#    Gender  Bed_time_hours  Wakeup_time_hours
# 0    Male              23                  5
# 1  Female              21                  4
# 2    Male              23                  6
# 3  Female              21                  4
# 4    Male              22                  5

# %%
df.columns
# Out:
# Index(['Person ID', 'Date', 'Sleep Duration (hrs)', 'Sleep Efficiency (%)',
#        'Bed Time', 'Wake Up Time', 'Deep Sleep (hrs)', 'Light Sleep (hrs)',
#        'REM Sleep (hrs)', 'Time unable to sleep/Others (hrs)', 'Age', 'Gender',
#        'Bed_time_hours', 'Wakeup_time_hours'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Person ID                          300 non-null    object
#  1   Date                               300 non-null    object
#  2   Sleep Duration (hrs)               300 non-null    float64
#  3   Sleep Efficiency (%)               300 non-null    float64
#  4   Bed Time                           300 non-null    datetime64[ns]
#  5   Wake Up Time                       300 non-null    datetime64[ns]
#  6   Deep Sleep (hrs)                   300 non-null    float64
#  7   Light Sleep (hrs)                  300 non-null    float64
#  8   REM Sleep (hrs)                    300 non-null    float64
#  9   Time unable to sleep/Others (hrs)  300 non-null    float64
#  10  Age                                300 non-null    int64
#  11  Gender                             300 non-null    object
#  12  Bed_time_hours                     300 non-null    int32
#  13  Wakeup_time_hours                  300 non-null    int32
# dtypes: datetime64[ns](2), float64(6), int32(2), int64(1), object(3)
# memory usage: 30.6+ KB

# %%
df.head()
# Out:
#   Person ID        Date  Sleep Duration (hrs)  Sleep Efficiency (%)  \
# 0  Person_1  2025-05-29              6.763567                 76.10
# 1  Person_2  2025-05-29              7.101986                 78.30
# 2  Person_3  2025-05-29              6.726011                 75.96
# 3  Person_4  2025-05-29              7.179961                 78.98
# 4  Person_5  2025-05-29              6.877313                 76.99
#
#              Bed Time                  Wake Up Time  Deep Sleep (hrs)  \
# 0 2025-05-31 23:06:00 2025-06-01 05:51:48.842830288          0.970121
# 1 2025-05-31 21:41:00 2025-06-01 04:47:07.148024820          0.962702
# 2 2025-05-31 23:40:00 2025-06-01 06:23:33.640384918          0.885353
# 3 2025-05-31 21:34:00 2025-06-01 04:44:47.859080926          1.045949
# 4 2025-05-31 22:55:00 2025-06-01 05:47:38.327794910          1.320055
#
#    Light Sleep (hrs)  REM Sleep (hrs)  Time unable to sleep/Others (hrs)  Age  \
# 0           2.700219         1.495712                           1.597515   56
# 1           3.172448         1.634347                           1.332489   46
# 2           2.813898         1.665220                           1.361541   32
# 3           2.985220         1.672419                           1.476373   60
# 4           2.794770         1.558585                           1.203904   25
#
#    Gender  Bed_time_hours  Wakeup_time_hours
# 0    Male              23                  5
# 1  Female              21                  4
# 2    Male              23                  6
# 3  Female              21                  4
# 4    Male              22                  5

# %%
df.drop(['Person ID','Date','Bed Time','Wake Up Time'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Sleep Duration (hrs)  Sleep Efficiency (%)  Deep Sleep (hrs)  \
# 0              6.763567                 76.10          0.970121
# 1              7.101986                 78.30          0.962702
# 2              6.726011                 75.96          0.885353
# 3              7.179961                 78.98          1.045949
# 4              6.877313                 76.99          1.320055
#
#    Light Sleep (hrs)  REM Sleep (hrs)  Time unable to sleep/Others (hrs)  Age  \
# 0           2.700219         1.495712                           1.597515   56
# 1           3.172448         1.634347                           1.332489   46
# 2           2.813898         1.665220                           1.361541   32
# 3           2.985220         1.672419                           1.476373   60
# 4           2.794770         1.558585                           1.203904   25
#
#    Gender  Bed_time_hours  Wakeup_time_hours
# 0    Male              23                  5
# 1  Female              21                  4
# 2    Male              23                  6
# 3  Female              21                  4
# 4    Male              22                  5

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.drop('Gender', axis=1).corr(), annot=True)
# Out:
# <Axes: >

# %%
def feature_selection(df, threshold):
    corr_matrix = df.corr()
    corr_set = set()
    for i in range(len(df.columns)):
        for j in range(i):
            if (abs(corr_matrix.iloc[i][j]) > threshold):
                corr_set.add(corr_matrix.columns[i])
    return corr_set

excess = feature_selection(df.drop('Gender',axis=1),0.85)
if 'Sleep Efficiency (%)' in excess:
    excess.remove('Sleep Efficiency (%)')
# Out:
# C:\Users\agary\AppData\Local\Temp\ipykernel_25640\3186767864.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (abs(corr_matrix.iloc[i][j]) > threshold):

# %%
df.drop(excess,axis=1,inplace=True)

# %%
df.head()
# Out:
#    Sleep Duration (hrs)  Sleep Efficiency (%)  Deep Sleep (hrs)  \
# 0              6.763567                 76.10          0.970121
# 1              7.101986                 78.30          0.962702
# 2              6.726011                 75.96          0.885353
# 3              7.179961                 78.98          1.045949
# 4              6.877313                 76.99          1.320055
#
#    Time unable to sleep/Others (hrs)  Age  Gender  Bed_time_hours  \
# 0                           1.597515   56    Male              23
# 1                           1.332489   46  Female              21
# 2                           1.361541   32    Male              23
# 3                           1.476373   60  Female              21
# 4                           1.203904   25    Male              22
#
#    Wakeup_time_hours
# 0                  5
# 1                  4
# 2                  6
# 3                  4
# 4                  5

# %%
df.to_csv('../datasets/sleep_cleaned.csv',index=False)
